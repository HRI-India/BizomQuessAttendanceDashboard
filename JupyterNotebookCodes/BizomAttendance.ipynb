# %%
import pandas as pd

# %%
bizom_April = pd.read_excel('/content/BizomAttendance.csv.xlsx')

# %%
bizom_April = bizom_April.to_csv('bizom_April.csv')

# %%
bizom_April = pd.read_csv('/content/bizom_April.csv')

# %%
bizom_April.head()
# Out:
#    Unnamed: 0        Date        Day Division   Zones   State  \
# 0           0  2025-04-20     Sunday       GT  WEST I  MUMBAI
# 1           1  2025-04-19   Saturday       GT  WEST I  MUMBAI
# 2           2  2025-04-18     Friday       GT  WEST I  MUMBAI
# 3           3  2025-04-17   Thursday       GT  WEST I  MUMBAI
# 4           4  2025-04-16  Wednesday       GT  WEST I  MUMBAI
#
#                                    CSA/DP_name  EMP_ID  User_ID  \
# 0  ABDUL GAFFAR ABDUL MAJID AND CO - DIRECT SS  330697       21
# 1  ABDUL GAFFAR ABDUL MAJID AND CO - DIRECT SS  330697       21
# 2  ABDUL GAFFAR ABDUL MAJID AND CO - DIRECT SS  330697       21
# 3  ABDUL GAFFAR ABDUL MAJID AND CO - DIRECT SS  330697       21
# 4  ABDUL GAFFAR ABDUL MAJID AND CO - DIRECT SS  330697       21
#
#             User_name  ... First_Call_Time Last_Call_Time JC_Meeting  \
# 0  Satish Gupta[LEFT]  ...             NaN            NaN        NaN
# ...

# %%
bizom_April.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'Day', 'Division', 'Zones', 'State',
#        'CSA/DP_name', 'EMP_ID', 'User_ID', 'User_name', 'User_status',
#        'User_designation', 'Reporting_to', 'ASM_Name', 'Attendance_status',
#        'Attendance_time', 'Assigned_Beat_Id', 'Assigned_Beat_Name',
#        'Assigned_Beat_Outlet_Count', 'Working_Beat_Id', 'Working_Beat_Name',
#        'Working_Beat_Outlet_Count', 'TC', 'PC', 'NC', '%_Of_PC', 'Total_Cases',
#        'Total_PCs', 'Total_Amount', 'First_Call_Time', 'Last_Call_Time',
#        'JC_Meeting', 'First_call_Geo_fenced', 'Last_call_Geo_fenced',
#        'Total_Vist_Geo_fenced', 'First_call_Geo_fenced_Calltime',
#        'Last_call_Geo_fenced_Calltime_', 'PJP_Followed', 'ID'],
#       dtype='object')

# %%
bizom_April = bizom_April[[
    'Date', 'Day', 'Division', 'Zones', 'State', 'EMP_ID',
    'User_ID', 'User_name', 'User_status', 'User_designation',
    'Reporting_to', 'ASM_Name', 'Attendance_status',
    'Total_Vist_Geo_fenced', 'PJP_Followed'
]]

# %%
bizom_May = pd.read_csv('/content/Bizom_May.csv')

# %%
bizom_May.head()
# Out:
#          Date       Day Division   Zones   State  \
# 0  2025-05-20   Tuesday       GT  WEST I  MUMBAI
# 1  2025-05-19    Monday       GT  WEST I  MUMBAI
# 2  2025-05-18    Sunday       GT  WEST I  MUMBAI
# 3  2025-05-17  Saturday       GT  WEST I  MUMBAI
# 4  2025-05-16    Friday       GT  WEST I  MUMBAI
#
#                                    CSA/DP_name  EMP_ID  User_ID  \
# 0  ABDUL GAFFAR ABDUL MAJID AND CO - DIRECT SS  330697       21
# 1  ABDUL GAFFAR ABDUL MAJID AND CO - DIRECT SS  330697       21
# 2  ABDUL GAFFAR ABDUL MAJID AND CO - DIRECT SS  330697       21
# 3  ABDUL GAFFAR ABDUL MAJID AND CO - DIRECT SS  330697       21
# 4  ABDUL GAFFAR ABDUL MAJID AND CO - DIRECT SS  330697       21
#
#             User_name User_status  ... First_Call_Time Last_Call_Time  \
# 0  Satish Gupta[LEFT]    Inactive  ...             NaN            NaN
# 1  Satish Gupta[LEFT]    Inactive  ...             NaN            NaN
# ...

# %%
bizom_May.columns
# Out:
# Index(['Date', 'Day', 'Division', 'Zones', 'State', 'CSA/DP_name', 'EMP_ID',
#        'User_ID', 'User_name', 'User_status', 'User_designation',
#        'Reporting_to', 'ASM_Name', 'Attendance_status', 'Attendance_time',
#        'Assigned_Beat_Id', 'Assigned_Beat_Name', 'Assigned_Beat_Outlet_Count',
#        'Working_Beat_Id', 'Working_Beat_Name', 'Working_Beat_Outlet_Count',
#        'TC', 'PC', 'NC', '%_Of_PC', 'Total_Cases', 'Total_PCs', 'Total_Amount',
#        'First_Call_Time', 'Last_Call_Time', 'JC_Meeting',
#        'First_call_Geo_fenced', 'Last_call_Geo_fenced',
#        'Total_Vist_Geo_fenced', 'First_call_Geo_fenced_Calltime',
#        'Last_call_Geo_fenced_Calltime_', 'PJP_Followed', 'ID'],
#       dtype='object')

# %%
bizom_May = bizom_May[['Date', 'Day', 'Division', 'Zones', 'State', 'EMP_ID',
       'User_ID', 'User_name', 'User_status', 'User_designation',
       'Reporting_to', 'ASM_Name', 'Attendance_status',
       'Total_Vist_Geo_fenced', 'PJP_Followed',]]

# %%
bizom_June = pd.read_csv('/content/Bizom_June.csv')

# %%
bizom_June.columns
# Out:
# Index(['Date', 'Day', 'Division', 'Zones', 'State', 'CSA/DP_name', 'EMP_ID',
#        'User_ID', 'User_name', 'User_status', 'User_designation',
#        'Reporting_to', 'ASM_Name', 'Attendance_status', 'Attendance_time',
#        'Assigned_Beat_Id', 'Assigned_Beat_Name', 'Assigned_Beat_Outlet_Count',
#        'Working_Beat_Id', 'Working_Beat_Name', 'Working_Beat_Outlet_Count',
#        'TC', 'PC', 'NC', '%_Of_PC', 'Total_Cases', 'Total_PCs', 'Total_Amount',
#        'First_Call_Time', 'Last_Call_Time', 'JC_Meeting',
#        'First_call_Geo_fenced', 'Last_call_Geo_fenced',
#        'Total_Vist_Geo_fenced', 'First_call_Geo_fenced_Calltime',
#        'Last_call_Geo_fenced_Calltime_', 'PJP_Followed', 'ID'],
#       dtype='object')

# %%
bizom_June = bizom_June[['Date', 'Day', 'Division', 'Zones', 'State', 'EMP_ID',
       'User_ID', 'User_name', 'User_status', 'User_designation',
       'Reporting_to', 'ASM_Name', 'Attendance_status',
       'Total_Vist_Geo_fenced', 'PJP_Followed',]]

# %%
import pandas as pd

# Assuming quess_df_April, quess_df_May, and quess_df_June are already loaded
bizom_df_combined = pd.concat([bizom_April, bizom_May, bizom_June], ignore_index=True)

# Optional: Save to Excel
bizom_df_combined.to_excel("Bizom_Combined.xlsx", index=False)

# %%
bizom_df_combined.columns
# Out:
# Index(['Date', 'Day', 'Division', 'Zones', 'State', 'EMP_ID', 'User_ID',
#        'User_name', 'User_status', 'User_designation', 'Reporting_to',
#        'ASM_Name', 'Attendance_status', 'Total_Vist_Geo_fenced',
#        'PJP_Followed'],
#       dtype='object')

# %%
bizom_df_combined.head()
# Out:
#          Date        Day Division   Zones   State  EMP_ID  User_ID  \
# 0  2025-04-20     Sunday       GT  WEST I  MUMBAI  330697       21
# 1  2025-04-19   Saturday       GT  WEST I  MUMBAI  330697       21
# 2  2025-04-18     Friday       GT  WEST I  MUMBAI  330697       21
# 3  2025-04-17   Thursday       GT  WEST I  MUMBAI  330697       21
# 4  2025-04-16  Wednesday       GT  WEST I  MUMBAI  330697       21
#
#             User_name User_status User_designation        Reporting_to  \
# 0  Satish Gupta[LEFT]    Inactive               SO  Ajay G More [Left]
# 1  Satish Gupta[LEFT]    Inactive               SO  Ajay G More [Left]
# 2  Satish Gupta[LEFT]    Inactive               SO  Ajay G More [Left]
# 3  Satish Gupta[LEFT]    Inactive               SO  Ajay G More [Left]
# 4  Satish Gupta[LEFT]    Inactive               SO  Ajay G More [Left]
#
#   ASM_Name Attendance_status  Total_Vist_Geo_fenced PJP_Followed
# 0      NaN        Not Marked                    NaN           No
# ...

# %%
bizom_df_combined.tail()
# Out:
#         Unnamed: 0        Date        Day Division  Zones       State  \
# 372076         NaN  2025-05-25     Sunday       GT  SOUTH  TAMIL NADU
# 372077         NaN  2025-05-24   Saturday       GT  SOUTH  TAMIL NADU
# 372078         NaN  2025-05-23     Friday       GT  SOUTH  TAMIL NADU
# 372079         NaN  2025-05-22   Thursday       GT  SOUTH  TAMIL NADU
# 372080         NaN  2025-05-21  Wednesday       GT  SOUTH  TAMIL NADU
#
#             CSA/DP_name      EMP_ID  User_ID User_name  ... First_Call_Time  \
# 372076  HRIPL - CHENNAI  GS10459536     7111  B Balaji  ...             NaN
# 372077  HRIPL - CHENNAI  GS10459536     7111  B Balaji  ...             NaN
# 372078  HRIPL - CHENNAI  GS10459536     7111  B Balaji  ...             NaN
# 372079  HRIPL - CHENNAI  GS10459536     7111  B Balaji  ...             NaN
# 372080  HRIPL - CHENNAI  GS10459536     7111  B Balaji  ...             NaN
#
#        Last_Call_Time JC_Meeting First_call_Geo_fenced Last_call_Geo_fenced  \
# ...
